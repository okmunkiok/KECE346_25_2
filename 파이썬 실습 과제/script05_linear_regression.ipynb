# %% [markdown]
# <h1>선형 회귀 분석</h1>

# %% [markdown]
# # 라이브러리와 데이터

# %%
# libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split # 훈련/평가 데이터 분리
from sklearn.linear_model import LinearRegression    # 선형회귀 모델

# %%
# read data
df = pd.read_csv('data03_carseat.csv')
df.head()
# Out:
#    Sales SalesBin  CompPrice  Income  Advertising  Population  Price  \
# 0   9.50     High        138      73           11         276    120
# 1  11.22     High        111      48           16         260     83
# 2  10.06     High        113      35           10         269     80
# 3   7.40      Low        117     100            4         466     97
# 4   4.15      Low        141      64            3         340    128
#
#   ShelveLoc  Age  Education Urban   US  Dummy01  Dummy02  Dummy03  Dummy04  \
# 0       Bad   42         17   Yes  Yes       38        7        8       16
# 1      Good   65         10   Yes  Yes       21        5       23       12
# 2    Medium   59         12   Yes  Yes       29        7        3       26
# 3    Medium   55         14   Yes  Yes       81        7       40       23
# 4       Bad   38         13   Yes   No       71        7        7       11
#
#    Dummy05  Dummy06
# 0      105       41
# 1      155       22
# 2      195       27
# 3      131       10
# 4      129       14

# %% [markdown]
# # 데이터 세팅

# %%
Y = df['Sales']
Xorg = df.iloc[:,2:]

# %%
Xorg.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0        138      73           11         276    120       Bad   42
# 1        111      48           16         260     83      Good   65
# 2        113      35           10         269     80    Medium   59
# 3        117     100            4         466     97    Medium   55
# 4        141      64            3         340    128       Bad   38
#
#    Education Urban   US  Dummy01  Dummy02  Dummy03  Dummy04  Dummy05  Dummy06
# 0         17   Yes  Yes       38        7        8       16      105       41
# 1         10   Yes  Yes       21        5       23       12      155       22
# 2         12   Yes  Yes       29        7        3       26      195       27
# 3         14   Yes  Yes       81        7       40       23      131       10
# 4         13   Yes   No       71        7        7       11      129       14

# %%
# making dummy variables
X = pd.get_dummies(Xorg,drop_first=True)

# %%
X.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  Age  Education  Dummy01  \
# 0        138      73           11         276    120   42         17       38
# 1        111      48           16         260     83   65         10       21
# 2        113      35           10         269     80   59         12       29
# 3        117     100            4         466     97   55         14       81
# 4        141      64            3         340    128   38         13       71
#
#    Dummy02  Dummy03  Dummy04  Dummy05  Dummy06  ShelveLoc_Good  \
# 0        7        8       16      105       41           False
# 1        5       23       12      155       22            True
# 2        7        3       26      195       27           False
# 3        7       40       23      131       10           False
# 4        7        7       11      129       14           False
#
#    ShelveLoc_Medium  Urban_Yes  US_Yes
# 0             False       True    True
# 1             False       True    True
# 2              True       True    True
# 3              True       True    True
# 4             False       True   False

# %%
xtrain_org, xtest_org, ytrain, ytest = train_test_split(X,Y,test_size=0.5,random_state=0)

# %%
print( xtrain_org.shape, xtest_org.shape )
# Out:
# (50, 17) (50, 17)

# %% [markdown]
# # 하나의 변수를 사용한 모델

# %%
# using one variables
xtrain = xtrain_org[['Income']]
xtest = xtest_org[['Income']]

# %%
f = LinearRegression()
f.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(f.coef_)
# Out:
# [0.0286964]

# %%
print(f.intercept_)
# Out:
# 5.447724035778486

# %%
# 훈련 데이터에 대한 예측
yhat_train = f.predict(xtrain)
plt.plot(xtrain,ytrain,'bo',xtrain,yhat_train,'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x7d04e9887bf0>,
#  <matplotlib.lines.Line2D at 0x7d04e98930b0>]

# %%
# 평가 데이터에 대한 예측
yhat_test = f.predict(xtest)
plt.plot(xtest,ytest,'bo',xtest,yhat_test,'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x7d04e8ca5d90>,
#  <matplotlib.lines.Line2D at 0x7d04e8ca5c70>]

# %%
# 훈련 데이터에 대한 R2 평가
f.score(xtrain,ytrain)
# Out:
# 0.05134515694950703

# %%
# 평가 데이터에 대한 R2 평가
f.score(xtest,ytest)
# Out:
# 0.018129246562816892

# %%
# 훈련 데이터에 대한 RMSE 평가
np.sqrt( ((ytrain-yhat_train)**2).mean() )
# Out:
# np.float64(3.0384678329694825)

# %%
# 평가 데이터에 대한 RMSE 평가
np.sqrt( ((ytest-yhat_test)**2).mean() )
# Out:
# np.float64(3.0098250608228505)

# %% [markdown]
# # 모든 변수를 다 사용한 모델

# %%
xtrain = xtrain_org
xtest = xtest_org

f = LinearRegression()
f.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
print(f.intercept_,f.coef_)
# Out:
# 3.0337229680839606 [ 1.12029366e-01  2.27645136e-02  2.07930613e-01 -5.48026875e-04
#  -9.05831523e-02 -4.02504902e-02 -3.28814056e-02 -4.78899246e-03
#  -1.02347172e-01  1.35263800e-02  2.04256841e-03 -4.96267963e-03
#   2.13824693e-02  4.75747264e+00  1.57365566e+00  3.17019410e-02
#  -7.64112662e-01]

# %%
print(f.score(xtrain,ytrain),f.score(xtest,ytest))
# Out:
# 0.9365084460305519 0.8574697965573882

# %% [markdown]
# # 불필요한 변수를 제거한 모델

# %%
xtrain = xtrain_org.iloc[:,[0,1,2,3,4,5,6,13,14,15,16]]
xtest = xtest_org.iloc[:,[0,1,2,3,4,5,6,13,14,15,16]]

f = LinearRegression()
f.fit(xtrain,ytrain)

print(f.score(xtrain,ytrain),f.score(xtest,ytest))
# Out:
# 0.9148283997074489 0.8707233967285173

# %% [markdown]
# # 연습문제

# %% [markdown]
# 1. 위의 선형 회귀 모델에서 변수를 세 개만 사용한다고 했을 때, 평가 데이터에서 가장 좋은 성능을 보이는 조합은 어떤 것인가?

# %% [markdown]
# 2. data01_iris에서 Sepal Length를 예측하기 위해 다른 변수로 이용하여 선형 회귀 모델을 학습하시오. 임의로 절반의 데이터는 훈련 데이터로 나머지 절반은 평가 데이터로 사용하시오. 학습된 모델과 훈련 및 평가 데이터에서의 성능을 보고하시오.
